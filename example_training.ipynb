# %% [markdown]
# # ReActure Dataset - ML Training Example
#
# This notebook demonstrates how to load and use ReActure datasets for machine learning.
#
# ## Requirements
# ```bash
# pip install numpy torch matplotlib
# ```
